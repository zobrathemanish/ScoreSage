# %%
import numpy as np
import pandas as pd
# Remove the limit on the number of columns displayed
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("modelling_table.csv")

# %%
df.tail()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Team 1 Score, Team 2 Score, Prev Team 1 Form, Prev Team 2 Form, Prev Team 2 Goal Difference, Prev Team 2 Points, Prev Team 2 Form.1, Cumulative_Avg_HST, Cumulative_Avg_AST, Cumulative_Avg_HF, Cumulative_Avg_AF, Cumulative_Avg_HC, Cumulative_Avg_AC, Cumulative_Avg_HY, team_1_fdr, team_2_fdr, Cumulative_Avg_AY, Cumulative_Avg_HR, Cumulative_Avg_AR, H2H_Home_Total_Wins_Last_4, H2H_Away_Total_Wins_Last_4, H2H_Draws_Last_4, Cum PPDA Team 2, Avg PPDA Team 1, Avg PPDA Team 2, Avg Deep Completions Team 1, Avg Deep Completions Team 2, Weighted Avg PPDA Team 1, Weighted Avg PPDA Team 2, Weighted Avg Deep Completions Team 1, Weighted Avg Deep Completions Team 2, Avg xG, Weighted Avg xG, Avg xG.1, Weighted Avg xG.1, Avg xG Team 1, Avg xG Team 2, Weighted Avg xG Team 1, Weighted Avg xG Team 2, Cum np_xg, Avg team1_np_xg, Avg team2_np_xg, Weighted Avg team1_np_xg, Weighted Avg team2_np_xg, Avg team1_expected_points, Avg team2_expected_points, Weighted Avg team1_expected_points, Weighted Avg team2_expected_points, Avg Team 1 Won, Avg Team 2 Won, Avg Team 1 Drawn, Avg Team 2 Drawn, Avg Team 1 Lost, Avg Team 2 Lost, Avg Team 1 Goals Scored, Avg Team 2 Goals Scored, Avg Team 1 Goals Conceded, Avg Team 2 Goals Conceded, Avg Team 1 Goal Difference, Avg Team 2 Goal Difference, time_period_encoded, ppg_team1, ppg_team2, team1_player_average, team2_player_average]
# Index: []

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the original data
data = df

# Select only numeric features for correlation calculation
numeric_features = data.select_dtypes(include=[np.number])

# Calculate correlation with 'Team 1 Score' and 'Team 2 Score'
score_correlations_1 = numeric_features.corrwith(data['Team 1 Score']).sort_values(ascending=True)
score_correlations_2 = numeric_features.corrwith(data['Team 2 Score']).sort_values(ascending=True)

# Plotting the correlation values for Team 1 Score
plt.figure(figsize=(10, 20))
score_correlations_1.plot(kind='barh', color='skyblue')
plt.title('Feature Correlation with Team 1 Score')
plt.xlabel('Correlation Coefficient')
plt.ylabel('Features')
plt.show()

# Plotting the correlation values for Team 2 Score
plt.figure(figsize=(10, 20))
score_correlations_2.plot(kind='barh', color='lightgreen')
plt.title('Feature Correlation with Team 2 Score')
plt.xlabel('Correlation Coefficient')
plt.ylabel('Features')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 16
#      14 # Plotting the correlation values for Team 1 Score
#      15 plt.figure(figsize=(10, 20))
# ---> 16 score_correlations_1.plot(kind='barh', color='skyblue')
#      17 plt.title('Feature Correlation with Team 1 Score')
#      18 plt.xlabel('Correlation Coefficient')
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:460, in MPLPlot.generate(self)
#     458 for ax in self.axes:
#     459     self._post_plot_logic_common(ax, self.data)
# --> 460     self._post_plot_logic(ax, self.data)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:1757, in BarPlot._post_plot_logic(self, ax, data)
#    1754 else:
#    1755     str_index = [pprint_thing(key) for key in range(data.shape[0])]
# -> 1757 s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    1758 e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    1760 self._decorate_ticks(ax, self._get_index_name(), str_index, s_edge, e_edge)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load your data
data_path = 'modelling_table.csv'  # Update your path accordingly
data = pd.read_csv(data_path)

# Example features you might want to plot
features_to_plot = ['Prev Team 1 Form', 'Avg xG Team 1', 'Avg PPDA Team 1']

# Plotting
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
for idx, feature in enumerate(features_to_plot):
    sns.scatterplot(x=feature, y='Team 1 Score', data=data, ax=axes[idx])
    axes[idx].set_title(f'Scatter plot: {feature} vs Team 1 Score')
    axes[idx].set_xlabel(feature)
    axes[idx].set_ylabel('Team 1 Score')

plt.tight_layout()
plt.show()

# %%
# plt.scatter(data['Temperature'], data['Team 1 Score'])
# plt.title('Temperature vs. Team 1 Score')
# plt.xlabel('Temperature')
# plt.ylabel('Team 1 Score')
# plt.show()
