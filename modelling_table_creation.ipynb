# %% [markdown]
# # Load the dataset

# %%
import pandas as pd
# Remove the limit on the number of columns displayed
pd.set_option('display.max_columns', None)

# %%
fact_table = pd.read_csv("fact_table.csv")

# %%
fact_table.tail()
# Out:
#      Unnamed: 0.1  Match ID           Team 1          Team 2  Team 1 Score  \
# 194           194    497605      Aston Villa  Leicester City           NaN
# 195           195    497609  Manchester City        West Ham           NaN
# 196           196    497600         Brighton         Arsenal           NaN
# 197           197    497604           Fulham    Ipswich Town           NaN
# 198           198    497606        Liverpool  Manchester Utd           NaN
#
#      Team 2 Score Winner  Prev Team 1 Played  Prev Team 1 Won  \
# 194           NaN    NaN                  19                8
# 195           NaN    NaN                  19                9
# 196           NaN    NaN                  19                6
# 197           NaN    NaN                  19                7
# 198           NaN    NaN                  18               14
#
#      Prev Team 1 Drawn  Prev Team 1 Lost  Prev Team 1 Goals Scored  \
# 194                  5                 6                        28
# 195                  4                 6                        32
# 196                  9                 4                        29
# 197                  8                 4                        28
# 198                  3                 1                        45
#
#      Prev Team 1 Goals Conceded  Prev Team 1 Goal Difference  \
# 194                          31                           -3
# 195                          26                            6
# 196                          28                            1
# 197                          25                            3
# 198                          17                           28
#
#      Prev Team 1 Points  Prev Team 1 Form  Prev Team 2 Played  \
# 194                  29               1.4                  19
# 195                  31               1.0                  19
# 196                  27               0.8                  18
# 197                  29               1.4                  19
# 198                  45               2.2                  19
#
#      Prev Team 2 Won  Prev Team 2 Drawn  Prev Team 2 Lost  \
# 194                3                  5                11
# 195                6                  5                 8
# 196               10                  6                 2
# 197                3                  6                10
# 198                6                  4                 9
#
#      Prev Team 2 Goals Scored  Prev Team 2 Goals Conceded  \
# 194                        22                          42
# 195                        23                          35
# 196                        35                          16
# 197                        18                          33
# 198                        21                          26
#
#      Prev Team 2 Goal Difference  Prev Team 2 Points  Prev Team 2 Form  \
# 194                          -20                  14               0.2
# 195                          -12                  23               1.6
# 196                           19                  36               2.2
# 197                          -15                  15               1.2
# 198                           -5                  22               0.6
#
#            Date      Time  Wk  Day  xG  xG.1  Attendance  \
# 194  2025-01-04  15:00:00  20  Sat NaN   NaN         NaN
# 195  2025-01-04  15:00:00  20  Sat NaN   NaN         NaN
# 196  2025-01-04  17:30:00  20  Sat NaN   NaN         NaN
# 197  2025-01-05  14:00:00  20  Sun NaN   NaN         NaN
# 198  2025-01-05  16:30:00  20  Sun NaN   NaN         NaN
#
#                             Venue Referee  StadiumID  Latitude  Longitude  \
# 194                    Villa Park     NaN         17   52.5092    -1.8840
# 195                Etihad Stadium     NaN         14   53.4831    -2.2003
# 196  The American Express Stadium     NaN         11   50.8618    -0.0833
# 197                Craven Cottage     NaN         13   51.4750    -0.2217
# 198                       Anfield     NaN         20   53.4308    -2.9608
#
#                 Datetime  Temperature  H2H_Home_Total_Wins_Last_4  \
# 194  2025-01-04T15:00:00          NaN                         NaN
# 195  2025-01-04T15:00:00          NaN                         NaN
# 196  2025-01-04T17:30:00          NaN                         NaN
# 197  2025-01-05T14:00:00          NaN                         NaN
# 198  2025-01-05T16:30:00          NaN                         0.0
#
#      H2H_Away_Total_Wins_Last_4  H2H_Draws_Last_4  \
# 194                         NaN               NaN
# 195                         NaN               NaN
# 196                         NaN               NaN
# 197                         NaN               NaN
# 198                         0.0               0.0
#
#                              Composite Key team_2_code team_1_code  team_1_xg  \
# 194  2025-01-04_Aston Villa_Leicester City         LEI         AVL        NaN
# 195    2025-01-04_Manchester City_West Ham         WHU         MCI        NaN
# 196            2025-01-04_Brighton_Arsenal         ARS         BRI        NaN
# 197         2025-01-05_Fulham_Ipswich Town         IPS         FLH        NaN
# 198    2025-01-05_Liverpool_Manchester Utd         MUN         LIV        NaN
#
#      team_2_xg  is_result  has_data                                url  \
# 194        NaN      False     False  https://understat.com/match/26793
# 195        NaN      False     False  https://understat.com/match/26798
# 196        NaN      False     False  https://understat.com/match/26794
# 197        NaN      False     False  https://understat.com/match/26796
# 198        NaN      False     False  https://understat.com/match/26797
#
#      team2_points  team2_expected_points  team2_np_xg  team2_np_xg_difference  \
# 194           NaN                    NaN          NaN                     NaN
# 195           NaN                    NaN          NaN                     NaN
# 196           NaN                    NaN          NaN                     NaN
# 197           NaN                    NaN          NaN                     NaN
# 198           NaN                    NaN          NaN                     NaN
#
#      team2_ppda  team2_deep_completions  team1_points  team1_expected_points  \
# 194         NaN                     NaN           NaN                    NaN
# 195         NaN                     NaN           NaN                    NaN
# 196         NaN                     NaN           NaN                    NaN
# 197         NaN                     NaN           NaN                    NaN
# 198         NaN                     NaN           NaN                    NaN
#
#      team1_np_xg  team1_np_xg_difference  team1_ppda  team1_deep_completions  \
# 194          NaN                     NaN         NaN                     NaN
# 195          NaN                     NaN         NaN                     NaN
# 196          NaN                     NaN         NaN                     NaN
# 197          NaN                     NaN         NaN                     NaN
# 198          NaN                     NaN         NaN                     NaN
#
#      Unnamed: 0_x  gameweek  team_1_fdr  team_2_fdr  \
# 194         191.0      20.0         2.0         4.0
# 195         194.0      20.0         2.0         4.0
# 196         196.0      20.0         4.0         3.0
# 197         197.0      20.0         2.0         3.0
# 198         198.0      20.0         3.0         5.0
#
#                              composite_key  B365H  B365D  B365A  HST  AST  HF  \
# 194  2025-01-04_Aston Villa_Leicester City    NaN    NaN    NaN  NaN  NaN NaN
# 195    2025-01-04_Manchester City_West Ham    NaN    NaN    NaN  NaN  NaN NaN
# 196            2025-01-04_Brighton_Arsenal    NaN    NaN    NaN  NaN  NaN NaN
# 197         2025-01-05_Fulham_Ipswich Town    NaN    NaN    NaN  NaN  NaN NaN
# 198    2025-01-05_Liverpool_Manchester Utd    NaN    NaN    NaN  NaN  NaN NaN
#
#      AF  HC  AC  HY  AY  HR  AR  team1_player_average  team2_player_average  \
# 194 NaN NaN NaN NaN NaN NaN NaN              8.962402              6.759556
# 195 NaN NaN NaN NaN NaN NaN NaN             11.150033              4.701582
# 196 NaN NaN NaN NaN NaN NaN NaN              6.742145              0.000000
# 197 NaN NaN NaN NaN NaN NaN NaN              9.137281              6.752342
# 198 NaN NaN NaN NaN NaN NaN NaN             11.470604              8.859151
#
#      Unnamed: 0  Score  Away Win Odds  Home Win Odds  Draw Odds  \
# 194       194.0    NaN            7.5           1.25       4.33
# 195       195.0    NaN            NaN            NaN        NaN
# 196       196.0    NaN            NaN            NaN        NaN
# 197       197.0    NaN            5.0           1.44       3.40
# 198       198.0    NaN            NaN            NaN        NaN
#
#      Precipitation  Cum Team 1 FDR  Cum Team 2 FDR  Avg Team 1 FDR  \
# 194            NaN            59.0            65.0            2.95
# 195            NaN            59.0            64.0            2.95
# 196            NaN            64.0            62.0            3.20
# 197            NaN            59.0            63.0            2.95
# 198            NaN             NaN            63.0             NaN
#
#      Avg Team 2 FDR  Cum PPDA Team 1  Cum PPDA Team 2  Avg PPDA Team 1  \
# 194            3.25       270.459756       315.625745        14.234724
# 195            3.20       242.242066       260.481212        12.749582
# 196            3.10       183.419703              NaN         9.653669
# 197            3.15       263.895481       273.069831        13.889236
# 198            3.15              NaN       204.957345              NaN
#
#      Avg PPDA Team 2  Cum Deep Completions Team 1  \
# 194        16.611881                        149.0
# 195        13.709537                        242.0
# 196              NaN                        153.0
# 197        14.372096                        111.0
# 198        10.787229                          NaN
#
#      Cum Deep Completions Team 2  Avg Deep Completions Team 1  \
# 194                         85.0                     7.842105
# 195                        122.0                    12.736842
# 196                          NaN                     8.052632
# 197                         73.0                     5.842105
# 198                        132.0                          NaN
#
#      Avg Deep Completions Team 2  Weighted Avg PPDA Team 1  \
# 194                     4.473684                 42.704172
# 195                     6.421053                 38.248747
# 196                          NaN                 30.485269
# 197                     3.842105                 41.667707
# 198                     6.947368                       NaN
#
#      Weighted Avg PPDA Team 2  Weighted Avg Deep Completions Team 1  \
# 194                 53.332882                             23.526316
# 195                 43.293276                             38.210526
# 196                       NaN                             25.429363
# 197                 45.385567                             17.526316
# 198                 32.929435                                   NaN
#
#      Weighted Avg Deep Completions Team 2  Cum xG    Avg xG  Weighted Avg xG  \
# 194                             14.362881       0  1.526316         4.502632
# 195                             20.277008       0  1.789474         5.278947
# 196                                   NaN       0  1.378947         4.412632
# 197                             12.132964       0  1.347368         3.974737
# 198                             21.207756       0  2.168421              NaN
#
#      Cum xG.1  Avg xG.1  Weighted Avg xG.1  Cum xG Team 1  Cum xG Team 2  \
# 194         0  0.989474           3.215789      35.126517      22.443229
# 195         0  1.421053           4.547368      37.401128      28.828157
# 196         0  1.636842           5.074211      29.594782            NaN
# 197         0  0.931579           2.934474      30.058187      22.143193
# 198         0  1.400000           4.410000            NaN      29.492857
#
#      Avg xG Team 1  Avg xG Team 2  Weighted Avg xG Team 1  \
# 194       1.848764       1.181223                5.453854
# 195       1.968480       1.517271                5.807017
# 196       1.557620            NaN                4.984384
# 197       1.582010       1.165431                4.666929
# 198            NaN       1.552256                     NaN
#
#      Weighted Avg xG Team 2  Cum np_xg  Avg team1_np_xg  Avg team2_np_xg  \
# 194                3.838973  53.763907         1.728579         1.101100
# 195                4.855269  62.423445         1.888358         1.397087
# 196                     NaN  67.530545         1.557620         1.996619
# 197                3.671108  49.917869         1.501887         1.125370
# 198                4.889605  71.160617         2.273163         1.472133
#
#      Weighted Avg team1_np_xg  Weighted Avg team2_np_xg  Cum expected_points  \
# 194                  5.099309                  3.578575              46.3629
# 195                  5.570655                  4.470677              50.0433
# 196                  4.984384                  6.189519              63.2812
# 197                  4.430566                  3.544914              44.8127
# 198                       NaN                  4.637219              69.3873
#
#      Avg team1_expected_points  Avg team2_expected_points  \
# 194                   1.626495                   0.813658
# 195                   1.577689                   1.056168
# 196                   1.403374                   1.927216
# 197                   1.606774                   0.751789
# 198                   2.194621                   1.457342
#
#      Weighted Avg team1_expected_points  Weighted Avg team2_expected_points  \
# 194                            4.798159                            2.644388
# 195                            4.654184                            3.379739
# 196                            4.490796                            5.974369
# 197                            4.739982                            2.368137
# 198                                 NaN                            4.590628
#
#      Cum Team 1 Won  Cum Team 2 Won  Avg Team 1 Won  Avg Team 2 Won  \
# 194              93              31        4.894737        1.631579
# 195             113              57        5.947368        3.000000
# 196              79             106        4.157895        5.578947
# 197              74              14        3.894737        0.736842
# 198             148              67        7.789474        3.526316
#
#      Cum Team 1 Drawn  Cum Team 2 Drawn  Avg Team 1 Drawn  Avg Team 2 Drawn  \
# 194                47                65          2.473684          3.421053
# 195                36                46          1.894737          2.421053
# 196                77                61          4.052632          3.210526
# 197                64                80          3.368421          4.210526
# 198                21                46          1.105263          2.421053
#
#      Cum Team 1 Lost  Cum Team 2 Lost  Avg Team 1 Lost  Avg Team 2 Lost  \
# 194               50               94         2.631579         4.947368
# 195               41               87         2.157895         4.578947
# 196               34               22         1.789474         1.157895
# 197               52               96         2.736842         5.052632
# 198               16               77         0.842105         4.052632
#
#      Cum Team 1 Goals Scored  Cum Team 2 Goals Scored  \
# 194                      301                      244
# 195                      369                      243
# 196                      317                      356
# 197                      267                      175
# 198                      388                      211
#
#      Avg Team 1 Goals Scored  Avg Team 2 Goals Scored  \
# 194                15.842105                12.842105
# 195                19.421053                12.789474
# 196                16.684211                18.736842
# 197                14.052632                 9.210526
# 198                20.421053                11.105263
#
#      Cum Team 1 Goals Conceded  Cum Team 2 Goals Conceded  \
# 194                        290                        379
# 195                        243                        336
# 196                        258                        175
# 197                        243                        358
# 198                        127                        227
#
#      Avg Team 1 Goals Conceded  Avg Team 2 Goals Conceded  \
# 194                  15.263158                  19.947368
# 195                  12.789474                  17.684211
# 196                  13.578947                   9.210526
# 197                  12.789474                  18.842105
# 198                   6.684211                  11.947368
#
#      Cum Team 1 Goal Difference  Cum Team 2 Goal Difference  \
# 194                          11                        -135
# 195                         126                         -93
# 196                          59                         181
# 197                          24                        -183
# 198                         261                         -16
#
#      Avg Team 1 Goal Difference  Avg Team 2 Goal Difference  \
# 194                    0.578947                   -7.105263
# 195                    6.631579                   -4.894737
# 196                    3.105263                    9.526316
# 197                    1.263158                   -9.631579
# 198                   13.736842                   -0.842105
#
#      Cum Team 1 Points  Cum Team 2 Points  Avg Team 1 Points  \
# 194                326                158          17.157895
# 195                375                217          19.736842
# 196                314                379          16.526316
# 197                286                122          15.052632
# 198                465                247          24.473684
#
#      Avg Team 2 Points Sunset_Time Match_Time_Category  ppg_team1  ppg_team2  \
# 194           8.315789    16:00:00             Daytime   1.526316   0.736842
# 195          11.421053    16:00:00             Daytime   1.631579   1.210526
# 196          19.947368    16:00:00           Nighttime   1.421053   2.000000
# 197           6.421053    16:00:00             Daytime   1.526316   0.789474
# 198          13.000000    16:00:00           Nighttime   2.500000   1.157895
#
#      Cumulative_Avg_HST  Cumulative_Avg_AST  Cumulative_Avg_HF  \
# 194            4.842105            4.631579          11.631579
# 195            4.842105            4.947368          10.526316
# 196                 NaN                 NaN                NaN
# 197            4.894737            4.052632          10.368421
# 198            4.368421            4.263158          10.947368
#
#      Cumulative_Avg_AF  Cumulative_Avg_HC  Cumulative_Avg_AC  \
# 194          11.000000           5.421053           4.894737
# 195          11.000000           6.210526           5.157895
# 196                NaN                NaN                NaN
# 197          12.315789           5.894737           5.105263
# 198          10.526316           5.368421           4.000000
#
#      Cumulative_Avg_HY  Cumulative_Avg_AY  Cumulative_Avg_HR  \
# 194           2.421053           2.105263           0.105263
# 195           1.947368           1.842105           0.000000
# 196                NaN                NaN                NaN
# 197           1.947368           2.105263           0.105263
# 198           2.000000           2.105263           0.105263
#
#      Cumulative_Avg_AR
# 194           0.000000
# 195           0.105263
# 196                NaN
# 197           0.052632
# 198           0.052632

# %%
# Re-import necessary libraries due to reset
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply label encoding
fact_table['time_period_encoded'] = label_encoder.fit_transform(fact_table['Match_Time_Category'])

# Display the results
# fact_table, dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

# %%
dataset = fact_table[['Team 1','Team 2','Team 1 Score', 'Team 2 Score','Prev Team 1 Form',
                      'Prev Team 2 Form','Prev Team 1 Goal Difference',
                      'Prev Team 2 Goal Difference','Prev Team 1 Points','Prev Team 2 Points',
                      'Cumulative_Avg_HST','Cumulative_Avg_AST','Cumulative_Avg_HF','Cumulative_Avg_AF',	
'Cumulative_Avg_HC', 'Cumulative_Avg_AC', 'Cumulative_Avg_HY', 'team_1_fdr','team_2_fdr', 'Cumulative_Avg_AY',	
'Cumulative_Avg_HR', 'Cumulative_Avg_AR','H2H_Home_Total_Wins_Last_4', 'H2H_Away_Total_Wins_Last_4', 
'H2H_Draws_Last_4','Cum PPDA Team 2', 'Avg PPDA Team 1', 'Avg PPDA Team 2', 
'Avg Deep Completions Team 1', 'Avg Deep Completions Team 2', 'Weighted Avg PPDA Team 1', 
'Weighted Avg PPDA Team 2', 'Weighted Avg Deep Completions Team 1', 'Weighted Avg Deep Completions Team 2', 
'Avg xG', 'Weighted Avg xG', 'Avg xG.1', 'Weighted Avg xG.1', 'Avg xG Team 1', 'Avg xG Team 2',
'Weighted Avg xG Team 1', 'Weighted Avg xG Team 2', 'Cum np_xg', 'Avg team1_np_xg', 'Avg team2_np_xg', 
'Weighted Avg team1_np_xg', 'Weighted Avg team2_np_xg', 'Avg team1_expected_points', 
'Avg team2_expected_points', 'Weighted Avg team1_expected_points', 'Weighted Avg team2_expected_points',
'Avg Team 1 Won', 'Avg Team 2 Won', 'Avg Team 1 Drawn', 'Avg Team 2 Drawn', 'Avg Team 1 Lost', 'Avg Team 2 Lost',
'Avg Team 1 Goals Scored', 'Avg Team 2 Goals Scored', 'Avg Team 1 Goals Conceded', 'Avg Team 2 Goals Conceded', 
'Avg Team 1 Goal Difference','Avg Team 2 Goal Difference', 'time_period_encoded', 'ppg_team1', 'ppg_team2','team1_player_average','team2_player_average'
                    ]]

# %%
# prediction_dataset = fact_table[['Team 1', 'Team 2'] + list(dataset.columns)].tail(10)
prediction_dataset = dataset.tail(10).copy()

# %%
prediction_dataset.tail(10)
# Out:
#               Team 1          Team 2  Team 1 Score  Team 2 Score  \
# 189        Brentford         Arsenal           NaN           NaN
# 190        Tottenham   Newcastle Utd           NaN           NaN
# 191      Southampton       Brentford           NaN           NaN
# 192   Crystal Palace         Chelsea           NaN           NaN
# 193      Bournemouth         Everton           NaN           NaN
# 194      Aston Villa  Leicester City           NaN           NaN
# 195  Manchester City        West Ham           NaN           NaN
# 196         Brighton         Arsenal           NaN           NaN
# 197           Fulham    Ipswich Town           NaN           NaN
# 198        Liverpool  Manchester Utd           NaN           NaN
#
#      Prev Team 1 Form  Prev Team 2 Form  Prev Team 1 Goal Difference  \
# 189               0.8               2.2                            0
# 190               0.8               2.4                           13
# 191               0.2               0.8                          -27
# 192               1.6               1.4                           -7
# 193               1.8               1.2                            6
# 194               1.4               0.2                           -3
# 195               1.0               1.6                            6
# 196               0.8               2.2                            1
# 197               1.4               1.2                            3
# 198               2.2               0.6                           28
#
#      Prev Team 2 Goal Difference  Prev Team 1 Points  Prev Team 2 Points  \
# 189                           19                  24                  36
# 190                           11                  24                  32
# 191                            0                   6                  24
# 192                           15                  20                  35
# 193                           -9                  30                  17
# 194                          -20                  29                  14
# 195                          -12                  31                  23
# 196                           19                  27                  36
# 197                          -15                  29                  15
# 198                           -5                  45                  22
#
#      Cumulative_Avg_HST  Cumulative_Avg_AST  Cumulative_Avg_HF  \
# 189            5.777778            2.833333          10.888889
# 190            4.789474            4.000000          13.052632
# 191                 NaN                 NaN                NaN
# 192            5.578947            5.368421          13.631579
# 193                 NaN                 NaN                NaN
# 194            4.842105            4.631579          11.631579
# 195            4.842105            4.947368          10.526316
# 196                 NaN                 NaN                NaN
# 197            4.894737            4.052632          10.368421
# 198            4.368421            4.263158          10.947368
#
#      Cumulative_Avg_AF  Cumulative_Avg_HC  Cumulative_Avg_AC  \
# 189          10.333333           6.388889           3.222222
# 190          10.631579           5.210526           5.736842
# 191                NaN                NaN                NaN
# 192          10.894737           4.842105           5.000000
# 193                NaN                NaN                NaN
# 194          11.000000           5.421053           4.894737
# 195          11.000000           6.210526           5.157895
# 196                NaN                NaN                NaN
# 197          12.315789           5.894737           5.105263
# 198          10.526316           5.368421           4.000000
#
#      Cumulative_Avg_HY  team_1_fdr  team_2_fdr  Cumulative_Avg_AY  \
# 189           2.333333         4.0         4.0           2.444444
# 190           2.736842         3.0         4.0           2.210526
# 191                NaN         2.0         2.0                NaN
# 192           3.421053         4.0         3.0           2.473684
# 193                NaN         2.0         3.0                NaN
# 194           2.421053         2.0         4.0           2.105263
# 195           1.947368         2.0         4.0           1.842105
# 196                NaN         4.0         3.0                NaN
# 197           1.947368         2.0         3.0           2.105263
# 198           2.000000         3.0         5.0           2.105263
#
#      Cumulative_Avg_HR  Cumulative_Avg_AR  H2H_Home_Total_Wins_Last_4  \
# 189           0.055556           0.111111                         NaN
# 190           0.052632           0.052632                         NaN
# 191                NaN                NaN                         NaN
# 192           0.105263           0.052632                         NaN
# 193                NaN                NaN                         NaN
# 194           0.105263           0.000000                         NaN
# 195           0.000000           0.105263                         NaN
# 196                NaN                NaN                         NaN
# 197           0.105263           0.052632                         NaN
# 198           0.105263           0.052632                         0.0
#
#      H2H_Away_Total_Wins_Last_4  H2H_Draws_Last_4  Cum PPDA Team 2  \
# 189                         NaN               NaN       162.048375
# 190                         NaN               NaN       211.713639
# 191                         NaN               NaN              NaN
# 192                         NaN               NaN       210.683989
# 193                         NaN               NaN              NaN
# 194                         NaN               NaN       315.625745
# 195                         NaN               NaN       260.481212
# 196                         NaN               NaN              NaN
# 197                         NaN               NaN       273.069831
# 198                         0.0               0.0       204.957345
#
#      Avg PPDA Team 1  Avg PPDA Team 2  Avg Deep Completions Team 1  \
# 189        12.560255         9.002688                     6.333333
# 190         9.969133        11.142823                    10.368421
# 191        12.367355              NaN                     6.052632
# 192        13.709126        11.088631                     6.157895
# 193         9.788856              NaN                     7.315789
# 194        14.234724        16.611881                     7.842105
# 195        12.749582        13.709537                    12.736842
# 196         9.653669              NaN                     8.052632
# 197        13.889236        14.372096                     5.842105
# 198              NaN        10.787229                          NaN
#
#      Avg Deep Completions Team 2  Weighted Avg PPDA Team 1  \
# 189                     9.388889                 38.378556
# 190                     9.105263                 29.382708
# 191                          NaN                 40.356632
# 192                     9.157895                 43.291976
# 193                          NaN                 30.912178
# 194                     4.473684                 42.704172
# 195                     6.421053                 38.248747
# 196                          NaN                 30.485269
# 197                     3.842105                 41.667707
# 198                     6.947368                       NaN
#
#      Weighted Avg PPDA Team 2  Weighted Avg Deep Completions Team 1  \
# 189                 27.508212                             19.351852
# 190                 34.601398                             30.559557
# 191                       NaN                             19.750693
# 192                 32.682281                             19.445983
# 193                       NaN                             23.102493
# 194                 53.332882                             23.526316
# 195                 43.293276                             38.210526
# 196                       NaN                             25.429363
# 197                 45.385567                             17.526316
# 198                 32.929435                                   NaN
#
#      Weighted Avg Deep Completions Team 2    Avg xG  Weighted Avg xG  \
# 189                             28.688272  1.516667         4.709649
# 190                             28.274238  1.836842         5.418684
# 191                                   NaN  1.015789         3.250526
# 192                             26.991690  1.357895         4.345263
# 193                                   NaN  1.957895         6.069474
# 194                             14.362881  1.526316         4.502632
# 195                             20.277008  1.789474         5.278947
# 196                                   NaN  1.378947         4.412632
# 197                             12.132964  1.347368         3.974737
# 198                             21.207756  2.168421              NaN
#
#      Avg xG.1  Weighted Avg xG.1  Avg xG Team 1  Avg xG Team 2  \
# 189  1.727778           5.365205       1.626305       2.192117
# 190  1.694737           5.338421       2.093656       1.752172
# 191  1.436842           4.382368       1.258535            NaN
# 192  2.026316           5.977632       1.612646       2.167603
# 193  0.926316                NaN       2.094688            NaN
# 194  0.989474           3.215789       1.848764       1.181223
# 195  1.421053           4.547368       1.968480       1.517271
# 196  1.636842           5.074211       1.557620            NaN
# 197  0.931579           2.934474       1.582010       1.165431
# 198  1.400000           4.410000            NaN       1.552256
#
#      Weighted Avg xG Team 1  Weighted Avg xG Team 2  Cum np_xg  \
# 189                5.050104                6.807100  65.686910
# 190                6.176286                5.519341  70.787234
# 191                4.027311                     NaN  49.954860
# 192                5.160466                6.394429  68.780043
# 193                6.493533                     NaN  54.797291
# 194                5.453854                3.838973  53.763907
# 195                5.807017                4.855269  62.423445
# 196                4.984384                     NaN  67.530545
# 197                4.666929                3.671108  49.917869
# 198                     NaN                4.889605  71.160617
#
#      Avg team1_np_xg  Avg team2_np_xg  Weighted Avg team1_np_xg  \
# 189         1.541730         2.107542                  4.787479
# 190         2.053595         1.672049                  6.058106
# 191         1.168616         1.460587                  3.739573
# 192         1.572584         2.047418                  5.032269
# 193         1.854319         1.029749                  5.748387
# 194         1.728579         1.101100                  5.099309
# 195         1.888358         1.397087                  5.570655
# 196         1.557620         1.996619                  4.984384
# 197         1.501887         1.125370                  4.430566
# 198         2.273163         1.472133                       NaN
#
#      Weighted Avg team2_np_xg  Avg team1_expected_points  \
# 189                  6.544474                   1.234983
# 190                  5.266953                   1.579384
# 191                  4.454789                   0.693532
# 192                  6.039884                   1.341700
# 193                       NaN                   1.838579
# 194                  3.578575                   1.626495
# 195                  4.470677                   1.577689
# 196                  6.189519                   1.403374
# 197                  3.544914                   1.606774
# 198                  4.637219                   2.194621
#
#      Avg team2_expected_points  Weighted Avg team1_expected_points  \
# 189                   2.034283                            3.834948
# 190                   1.540937                            4.659183
# 191                   1.169984                            2.219301
# 192                   1.660679                            4.293440
# 193                   0.908995                            5.699595
# 194                   0.813658                            4.798159
# 195                   1.056168                            4.654184
# 196                   1.927216                            4.490796
# 197                   0.751789                            4.739982
# 198                   1.457342                                 NaN
#
#      Weighted Avg team2_expected_points  Avg Team 1 Won  Avg Team 2 Won  \
# 189                            6.316985        4.111111        5.333333
# 190                            4.853951        4.263158        4.263158
# 191                            3.568452        0.526316        4.263158
# 192                            4.899003        1.157895        5.473684
# 193                                 NaN        3.894737        1.684211
# 194                            2.644388        4.894737        1.631579
# 195                            3.379739        5.947368        3.000000
# 196                            5.974369        4.157895        5.578947
# 197                            2.368137        3.894737        0.736842
# 198                            4.590628        7.789474        3.526316
#
#      Avg Team 1 Drawn  Avg Team 2 Drawn  Avg Team 1 Lost  Avg Team 2 Lost  \
# 189          1.166667          3.055556         4.222222         1.111111
# 190          1.421053          3.052632         4.315789         2.684211
# 191          1.315789          1.263158         8.157895         4.421053
# 192          4.210526          2.736842         4.631579         1.789474
# 193          2.894737          3.421053         3.210526         4.631579
# 194          2.473684          3.421053         2.631579         4.947368
# 195          1.894737          2.421053         2.157895         4.578947
# 196          4.052632          3.210526         1.789474         1.157895
# 197          3.368421          4.210526         2.736842         5.052632
# 198          1.105263          2.421053         0.842105         4.052632
#
#      Avg Team 1 Goals Scored  Avg Team 2 Goals Scored  \
# 189                17.666667                17.833333
# 190                21.210526                13.210526
# 191                 6.473684                18.421053
# 192                 8.894737                21.315789
# 193                14.210526                 8.947368
# 194                15.842105                12.842105
# 195                19.421053                12.789474
# 196                16.684211                18.736842
# 197                14.052632                 9.210526
# 198                20.421053                11.105263
#
#      Avg Team 1 Goals Conceded  Avg Team 2 Goals Conceded  \
# 189                  17.444444                   8.833333
# 190                  12.052632                  11.263158
# 191                  20.368421                  18.210526
# 192                  14.052632                  11.842105
# 193                  13.052632                  16.315789
# 194                  15.263158                  19.947368
# 195                  12.789474                  17.684211
# 196                  13.578947                   9.210526
# 197                  12.789474                  18.842105
# 198                   6.684211                  11.947368
#
#      Avg Team 1 Goal Difference  Avg Team 2 Goal Difference  \
# 189                    0.222222                    9.000000
# 190                    9.157895                    1.947368
# 191                  -13.894737                    0.210526
# 192                   -5.157895                    9.473684
# 193                    1.157895                   -7.368421
# 194                    0.578947                   -7.105263
# 195                    6.631579                   -4.894737
# 196                    3.105263                    9.526316
# 197                    1.263158                   -9.631579
# 198                   13.736842                   -0.842105
#
#      time_period_encoded  ppg_team1  ppg_team2  team1_player_average  \
# 189                    1   1.333333   2.000000              9.277411
# 190                    0   1.263158   1.684211             11.427816
# 191                    0   0.315789   1.333333              8.363351
# 192                    0   1.052632   1.842105             10.914909
# 193                    0   1.578947   0.944444              8.929617
# 194                    0   1.526316   0.736842              8.962402
# 195                    0   1.631579   1.210526             11.150033
# 196                    1   1.421053   2.000000              6.742145
# 197                    0   1.526316   0.789474              9.137281
# 198                    1   2.500000   1.157895             11.470604
#
#      team2_player_average
# 189             10.900880
# 190              9.600594
# 191              0.000000
# 192             11.373515
# 193              9.039789
# 194              6.759556
# 195              4.701582
# 196              0.000000
# 197              6.752342
# 198              8.859151

# %%
len(prediction_dataset)
# Out:
# 10

# %%
prediction_dataset.to_csv("prediction_data.csv")

# %%
prediction_dataset.columns
# Out:
# Index(['Team 1', 'Team 2', 'Team 1 Score', 'Team 2 Score', 'Prev Team 1 Form',
#        'Prev Team 2 Form', 'Prev Team 1 Goal Difference',
#        'Prev Team 2 Goal Difference', 'Prev Team 1 Points',
#        'Prev Team 2 Points', 'Cumulative_Avg_HST', 'Cumulative_Avg_AST',
#        'Cumulative_Avg_HF', 'Cumulative_Avg_AF', 'Cumulative_Avg_HC',
#        'Cumulative_Avg_AC', 'Cumulative_Avg_HY', 'team_1_fdr', 'team_2_fdr',
#        'Cumulative_Avg_AY', 'Cumulative_Avg_HR', 'Cumulative_Avg_AR',
#        'H2H_Home_Total_Wins_Last_4', 'H2H_Away_Total_Wins_Last_4',
#        'H2H_Draws_Last_4', 'Cum PPDA Team 2', 'Avg PPDA Team 1',
#        'Avg PPDA Team 2', 'Avg Deep Completions Team 1',
#        'Avg Deep Completions Team 2', 'Weighted Avg PPDA Team 1',
#        'Weighted Avg PPDA Team 2', 'Weighted Avg Deep Completions Team 1',
#        'Weighted Avg Deep Completions Team 2', 'Avg xG', 'Weighted Avg xG',
#        'Avg xG.1', 'Weighted Avg xG.1', 'Avg xG Team 1', 'Avg xG Team 2',
#        'Weighted Avg xG Team 1', 'Weighted Avg xG Team 2', 'Cum np_xg',
#        'Avg team1_np_xg', 'Avg team2_np_xg', 'Weighted Avg team1_np_xg',
#        'Weighted Avg team2_np_xg', 'Avg team1_expected_points',
#        'Avg team2_expected_points', 'Weighted Avg team1_expected_points',
#        'Weighted Avg team2_expected_points', 'Avg Team 1 Won',
#        'Avg Team 2 Won', 'Avg Team 1 Drawn', 'Avg Team 2 Drawn',
#        'Avg Team 1 Lost', 'Avg Team 2 Lost', 'Avg Team 1 Goals Scored',
#        'Avg Team 2 Goals Scored', 'Avg Team 1 Goals Conceded',
#        'Avg Team 2 Goals Conceded', 'Avg Team 1 Goal Difference',
#        'Avg Team 2 Goal Difference', 'time_period_encoded', 'ppg_team1',
#        'ppg_team2', 'team1_player_average', 'team2_player_average'],
#       dtype='object')

# %%
prediction_dataset.head()
# Out:
#              Team 1         Team 2  Team 1 Score  Team 2 Score  \
# 189       Brentford        Arsenal           NaN           NaN
# 190       Tottenham  Newcastle Utd           NaN           NaN
# 191     Southampton      Brentford           NaN           NaN
# 192  Crystal Palace        Chelsea           NaN           NaN
# 193     Bournemouth        Everton           NaN           NaN
#
#      Prev Team 1 Form  Prev Team 2 Form  Prev Team 1 Goal Difference  \
# 189               0.8               2.2                            0
# 190               0.8               2.4                           13
# 191               0.2               0.8                          -27
# 192               1.6               1.4                           -7
# 193               1.8               1.2                            6
#
#      Prev Team 2 Goal Difference  Prev Team 1 Points  Prev Team 2 Points  \
# 189                           19                  24                  36
# 190                           11                  24                  32
# 191                            0                   6                  24
# 192                           15                  20                  35
# 193                           -9                  30                  17
#
#      Cumulative_Avg_HST  Cumulative_Avg_AST  Cumulative_Avg_HF  \
# 189            5.777778            2.833333          10.888889
# 190            4.789474            4.000000          13.052632
# 191                 NaN                 NaN                NaN
# 192            5.578947            5.368421          13.631579
# 193                 NaN                 NaN                NaN
#
#      Cumulative_Avg_AF  Cumulative_Avg_HC  Cumulative_Avg_AC  \
# 189          10.333333           6.388889           3.222222
# 190          10.631579           5.210526           5.736842
# 191                NaN                NaN                NaN
# 192          10.894737           4.842105           5.000000
# 193                NaN                NaN                NaN
#
#      Cumulative_Avg_HY  team_1_fdr  team_2_fdr  Cumulative_Avg_AY  \
# 189           2.333333         4.0         4.0           2.444444
# 190           2.736842         3.0         4.0           2.210526
# 191                NaN         2.0         2.0                NaN
# 192           3.421053         4.0         3.0           2.473684
# 193                NaN         2.0         3.0                NaN
#
#      Cumulative_Avg_HR  Cumulative_Avg_AR  H2H_Home_Total_Wins_Last_4  \
# 189           0.055556           0.111111                         NaN
# 190           0.052632           0.052632                         NaN
# 191                NaN                NaN                         NaN
# 192           0.105263           0.052632                         NaN
# 193                NaN                NaN                         NaN
#
#      H2H_Away_Total_Wins_Last_4  H2H_Draws_Last_4  Cum PPDA Team 2  \
# 189                         NaN               NaN       162.048375
# 190                         NaN               NaN       211.713639
# 191                         NaN               NaN              NaN
# 192                         NaN               NaN       210.683989
# 193                         NaN               NaN              NaN
#
#      Avg PPDA Team 1  Avg PPDA Team 2  Avg Deep Completions Team 1  \
# 189        12.560255         9.002688                     6.333333
# 190         9.969133        11.142823                    10.368421
# 191        12.367355              NaN                     6.052632
# 192        13.709126        11.088631                     6.157895
# 193         9.788856              NaN                     7.315789
#
#      Avg Deep Completions Team 2  Weighted Avg PPDA Team 1  \
# 189                     9.388889                 38.378556
# 190                     9.105263                 29.382708
# 191                          NaN                 40.356632
# 192                     9.157895                 43.291976
# 193                          NaN                 30.912178
#
#      Weighted Avg PPDA Team 2  Weighted Avg Deep Completions Team 1  \
# 189                 27.508212                             19.351852
# 190                 34.601398                             30.559557
# 191                       NaN                             19.750693
# 192                 32.682281                             19.445983
# 193                       NaN                             23.102493
#
#      Weighted Avg Deep Completions Team 2    Avg xG  Weighted Avg xG  \
# 189                             28.688272  1.516667         4.709649
# 190                             28.274238  1.836842         5.418684
# 191                                   NaN  1.015789         3.250526
# 192                             26.991690  1.357895         4.345263
# 193                                   NaN  1.957895         6.069474
#
#      Avg xG.1  Weighted Avg xG.1  Avg xG Team 1  Avg xG Team 2  \
# 189  1.727778           5.365205       1.626305       2.192117
# 190  1.694737           5.338421       2.093656       1.752172
# 191  1.436842           4.382368       1.258535            NaN
# 192  2.026316           5.977632       1.612646       2.167603
# 193  0.926316                NaN       2.094688            NaN
#
#      Weighted Avg xG Team 1  Weighted Avg xG Team 2  Cum np_xg  \
# 189                5.050104                6.807100  65.686910
# 190                6.176286                5.519341  70.787234
# 191                4.027311                     NaN  49.954860
# 192                5.160466                6.394429  68.780043
# 193                6.493533                     NaN  54.797291
#
#      Avg team1_np_xg  Avg team2_np_xg  Weighted Avg team1_np_xg  \
# 189         1.541730         2.107542                  4.787479
# 190         2.053595         1.672049                  6.058106
# 191         1.168616         1.460587                  3.739573
# 192         1.572584         2.047418                  5.032269
# 193         1.854319         1.029749                  5.748387
#
#      Weighted Avg team2_np_xg  Avg team1_expected_points  \
# 189                  6.544474                   1.234983
# 190                  5.266953                   1.579384
# 191                  4.454789                   0.693532
# 192                  6.039884                   1.341700
# 193                       NaN                   1.838579
#
#      Avg team2_expected_points  Weighted Avg team1_expected_points  \
# 189                   2.034283                            3.834948
# 190                   1.540937                            4.659183
# 191                   1.169984                            2.219301
# 192                   1.660679                            4.293440
# 193                   0.908995                            5.699595
#
#      Weighted Avg team2_expected_points  Avg Team 1 Won  Avg Team 2 Won  \
# 189                            6.316985        4.111111        5.333333
# 190                            4.853951        4.263158        4.263158
# 191                            3.568452        0.526316        4.263158
# 192                            4.899003        1.157895        5.473684
# 193                                 NaN        3.894737        1.684211
#
#      Avg Team 1 Drawn  Avg Team 2 Drawn  Avg Team 1 Lost  Avg Team 2 Lost  \
# 189          1.166667          3.055556         4.222222         1.111111
# 190          1.421053          3.052632         4.315789         2.684211
# 191          1.315789          1.263158         8.157895         4.421053
# 192          4.210526          2.736842         4.631579         1.789474
# 193          2.894737          3.421053         3.210526         4.631579
#
#      Avg Team 1 Goals Scored  Avg Team 2 Goals Scored  \
# 189                17.666667                17.833333
# 190                21.210526                13.210526
# 191                 6.473684                18.421053
# 192                 8.894737                21.315789
# 193                14.210526                 8.947368
#
#      Avg Team 1 Goals Conceded  Avg Team 2 Goals Conceded  \
# 189                  17.444444                   8.833333
# 190                  12.052632                  11.263158
# 191                  20.368421                  18.210526
# 192                  14.052632                  11.842105
# 193                  13.052632                  16.315789
#
#      Avg Team 1 Goal Difference  Avg Team 2 Goal Difference  \
# 189                    0.222222                    9.000000
# 190                    9.157895                    1.947368
# 191                  -13.894737                    0.210526
# 192                   -5.157895                    9.473684
# 193                    1.157895                   -7.368421
#
#      time_period_encoded  ppg_team1  ppg_team2  team1_player_average  \
# 189                    1   1.333333   2.000000              9.277411
# 190                    0   1.263158   1.684211             11.427816
# 191                    0   0.315789   1.333333              8.363351
# 192                    0   1.052632   1.842105             10.914909
# 193                    0   1.578947   0.944444              8.929617
#
#      team2_player_average
# 189             10.900880
# 190              9.600594
# 191              0.000000
# 192             11.373515
# 193              9.039789

# %%
dataset = dataset.iloc[10:-10]
df = dataset

# %%
# df['time_period_encoded']

# %%
df.columns
# Out:
# Index(['Team 1', 'Team 2', 'Team 1 Score', 'Team 2 Score', 'Prev Team 1 Form',
#        'Prev Team 2 Form', 'Prev Team 1 Goal Difference',
#        'Prev Team 2 Goal Difference', 'Prev Team 1 Points',
#        'Prev Team 2 Points', 'Cumulative_Avg_HST', 'Cumulative_Avg_AST',
#        'Cumulative_Avg_HF', 'Cumulative_Avg_AF', 'Cumulative_Avg_HC',
#        'Cumulative_Avg_AC', 'Cumulative_Avg_HY', 'team_1_fdr', 'team_2_fdr',
#        'Cumulative_Avg_AY', 'Cumulative_Avg_HR', 'Cumulative_Avg_AR',
#        'H2H_Home_Total_Wins_Last_4', 'H2H_Away_Total_Wins_Last_4',
#        'H2H_Draws_Last_4', 'Cum PPDA Team 2', 'Avg PPDA Team 1',
#        'Avg PPDA Team 2', 'Avg Deep Completions Team 1',
#        'Avg Deep Completions Team 2', 'Weighted Avg PPDA Team 1',
#        'Weighted Avg PPDA Team 2', 'Weighted Avg Deep Completions Team 1',
#        'Weighted Avg Deep Completions Team 2', 'Avg xG', 'Weighted Avg xG',
#        'Avg xG.1', 'Weighted Avg xG.1', 'Avg xG Team 1', 'Avg xG Team 2',
#        'Weighted Avg xG Team 1', 'Weighted Avg xG Team 2', 'Cum np_xg',
#        'Avg team1_np_xg', 'Avg team2_np_xg', 'Weighted Avg team1_np_xg',
#        'Weighted Avg team2_np_xg', 'Avg team1_expected_points',
#        'Avg team2_expected_points', 'Weighted Avg team1_expected_points',
#        'Weighted Avg team2_expected_points', 'Avg Team 1 Won',
#        'Avg Team 2 Won', 'Avg Team 1 Drawn', 'Avg Team 2 Drawn',
#        'Avg Team 1 Lost', 'Avg Team 2 Lost', 'Avg Team 1 Goals Scored',
#        'Avg Team 2 Goals Scored', 'Avg Team 1 Goals Conceded',
#        'Avg Team 2 Goals Conceded', 'Avg Team 1 Goal Difference',
#        'Avg Team 2 Goal Difference', 'time_period_encoded', 'ppg_team1',
#        'ppg_team2', 'team1_player_average', 'team2_player_average'],
#       dtype='object')

# %%
df.to_csv("modelling_table.csv")

# %%
df.columns
# Out:
# Index(['Team 1', 'Team 2', 'Team 1 Score', 'Team 2 Score', 'Prev Team 1 Form',
#        'Prev Team 2 Form', 'Prev Team 1 Goal Difference',
#        'Prev Team 2 Goal Difference', 'Prev Team 1 Points',
#        'Prev Team 2 Points', 'Cumulative_Avg_HST', 'Cumulative_Avg_AST',
#        'Cumulative_Avg_HF', 'Cumulative_Avg_AF', 'Cumulative_Avg_HC',
#        'Cumulative_Avg_AC', 'Cumulative_Avg_HY', 'team_1_fdr', 'team_2_fdr',
#        'Cumulative_Avg_AY', 'Cumulative_Avg_HR', 'Cumulative_Avg_AR',
#        'H2H_Home_Total_Wins_Last_4', 'H2H_Away_Total_Wins_Last_4',
#        'H2H_Draws_Last_4', 'Cum PPDA Team 2', 'Avg PPDA Team 1',
#        'Avg PPDA Team 2', 'Avg Deep Completions Team 1',
#        'Avg Deep Completions Team 2', 'Weighted Avg PPDA Team 1',
#        'Weighted Avg PPDA Team 2', 'Weighted Avg Deep Completions Team 1',
#        'Weighted Avg Deep Completions Team 2', 'Avg xG', 'Weighted Avg xG',
#        'Avg xG.1', 'Weighted Avg xG.1', 'Avg xG Team 1', 'Avg xG Team 2',
#        'Weighted Avg xG Team 1', 'Weighted Avg xG Team 2', 'Cum np_xg',
#        'Avg team1_np_xg', 'Avg team2_np_xg', 'Weighted Avg team1_np_xg',
#        'Weighted Avg team2_np_xg', 'Avg team1_expected_points',
#        'Avg team2_expected_points', 'Weighted Avg team1_expected_points',
#        'Weighted Avg team2_expected_points', 'Avg Team 1 Won',
#        'Avg Team 2 Won', 'Avg Team 1 Drawn', 'Avg Team 2 Drawn',
#        'Avg Team 1 Lost', 'Avg Team 2 Lost', 'Avg Team 1 Goals Scored',
#        'Avg Team 2 Goals Scored', 'Avg Team 1 Goals Conceded',
#        'Avg Team 2 Goals Conceded', 'Avg Team 1 Goal Difference',
#        'Avg Team 2 Goal Difference', 'time_period_encoded', 'ppg_team1',
#        'ppg_team2', 'team1_player_average', 'team2_player_average'],
#       dtype='object')
